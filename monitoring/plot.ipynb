# %%
import matplotlib.pyplot as plt

# %%
with open("data.txt", "r") as file:
    time = []
    values = []
    for line in file:
        columns = line.strip().split()
        read_time = columns[0].split(':')
        time.append(float(read_time[0])*60+float(read_time[1]))
        values.append(float(columns[1]))

# Plot data
plt.plot(time, values, '-')
plt.xlabel('Time')
plt.ylabel('%MEM')
plt.title('MEM% for connectedcomponent process')
plt.show()

# %%
with open("pagerank-graphchi.java.txt", "r") as file:
    time = []
    values = []
    i=0
    for line in file:
        columns = line.strip().split()
        time.append(i)
        values.append(float(columns[4]))
        i= i+1

# Plot data
plt.plot(time, values, '-')
plt.xlabel('Time')
plt.ylabel('Page Read')
plt.title('page Read over time')
plt.show()

# %%
with open("pagerank-graphchi.java.txt", "r") as file:
    time = []
    values = []
    i=0
    for line in file:
        columns = line.strip().split()
        time.append(i)
        values.append(float(columns[5]))
        i= i+1

# Plot data
plt.plot(time, values, '-')
plt.xlabel('Time')
plt.ylabel('Page Write')
plt.title('page Write over time')
plt.show()

# %%
with open("pagerank-graphchi.java.txt", "r") as file:
    time = []
    values = []
    i=0
    for line in file:
        columns = line.strip().split()
        time.append(i)
        values.append(float(columns[1]))
        i= i+1

# Plot data
plt.plot(time, values, '-')
plt.xlabel('Time')
plt.ylabel('Transfer per second')
plt.title('tps over time')
plt.show()

# %%
with open("pagerank-graphchi.java.txt", "r") as file:
    time = []
    reads = []
    writes = []
    i=0
    for line in file:
        columns = line.strip().split()
        time.append(i)
        reads.append(float(columns[4]))
        writes.append(float(columns[5]))
        i= i+1

# Plot data
plt.plot(time, reads,color='red', label= 'reads')
plt.plot(time, writes,color='blue',label = 'writes')
plt.xlabel('Time')
plt.ylabel('IO')
plt.title('page Read/Write over time')
plt.show()

# %%
with open("core_0_usage.log", "r") as file:
    time = []
    core = []
    i=0
    for line in file:
        time.append(i)
        core.append(float(line))
        i= i+1

# Plot data
plt.plot(time, core,color='red', label= 'core')
plt.xlabel('Time')
plt.ylabel('CPU% Usage')
plt.title('CPU usage over time')
plt.show()

# %%
with open("core_1_usage.log", "r") as file:
    time = []
    core = []
    i=0
    for line in file:
        time.append(i)
        core.append(float(line))
        i= i+1

# Plot data
plt.plot(time, core,color='red', label= 'core')
plt.xlabel('Time')
plt.ylabel('CPU% Usage')
plt.title('CPU usage over time')
plt.show()

# %%
with open("core_2_usage.log", "r") as file:
    time = []
    core = []
    i=0
    for line in file:
        time.append(i)
        core.append(float(line))
        i= i+1

# Plot data
plt.plot(time, core,color='red', label= 'core')
plt.xlabel('Time')
plt.ylabel('CPU% Usage')
plt.title('CPU usage over time')
plt.show()

# %%
with open("core_3_usage.log", "r") as file:
    time = []
    core = []
    i=0
    for line in file:
        time.append(i)
        core.append(float(line))
        i= i+1

# Plot data
plt.plot(time, core,color='red', label= 'core')
plt.xlabel('Time')
plt.ylabel('CPU% Usage')
plt.title('CPU usage over time')
plt.show()

# %%
with open("core_4_usage.log", "r") as file:
    time = []
    core = []
    i=0
    for line in file:
        time.append(i)
        core.append(float(line))
        i= i+1

# Plot data
plt.plot(time, core,color='red', label= 'core')
plt.xlabel('Time')
plt.ylabel('CPU% Usage')
plt.title('CPU usage over time')
plt.show()

# %%
with open("core_5_usage.log", "r") as file:
    time = []
    core = []
    i=0
    for line in file:
        time.append(i)
        core.append(float(line))
        i= i+1

# Plot data
plt.plot(time, core,color='red', label= 'core')
plt.xlabel('Time')
plt.ylabel('CPU% Usage')
plt.title('CPU usage over time')
plt.show()

# %%
with open("core_6_usage.log", "r") as file:
    time = []
    core = []
    i=0
    for line in file:
        time.append(i)
        core.append(float(line))
        i= i+1

# Plot data
plt.plot(time, core,color='red', label= 'core')
plt.xlabel('Time')
plt.ylabel('CPU% Usage')
plt.title('CPU usage over time')
plt.show()

# %%
with open("core_7_usage.log", "r") as file:
    time = []
    core = []
    i=0
    for line in file:
        time.append(i)
        core.append(float(line))
        i= i+1

# Plot data
plt.plot(time, core,color='red', label= 'core')
plt.xlabel('Time')
plt.ylabel('CPU% Usage')
plt.title('CPU usage over time')
plt.show()
